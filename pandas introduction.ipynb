# %%
import pandas as pd
import sys
import numpy as np

# %%
certificate_earned = pd.Series(
    [8,2,5,6],
    index=['Tom','Chris','James','David']
)
print(certificate_earned[certificate_earned > 5])
# Out:
# Tom      8
# David    6
# dtype: int64

# %%
certificate_earned.iloc[0]
# Out:
# 8

# %%
certificate_earned['Tom':'David']
# Out:
# Tom      8
# Chris    2
# James    5
# David    6
# dtype: int64

# %%
certificate_earned > 5
# Out:
# Tom       True
# Chris    False
# James    False
# David     True
# dtype: bool

# %%
certificate_earned.mean()
# Out:
# 5.25

# %%
certificate_earned[certificate_earned > certificate_earned.mean()]
# Out:
# Tom      8
# David    6
# dtype: int64

# %%
certificates = pd.DataFrame({
    'Certificates': [8, 2, 5, 6],
    'Time (in months)': [16, 5, 9, 12]
})

certificates.index = ['Tom', 'Kris', 'Ahmad', 'Beau']

print(certificates.iloc[2])
# Out:
# Certificates        5
# Time (in months)    9
# Name: Ahmad, dtype: int64

# %%
certificates_earned = pd.DataFrame({
    'Certificates': [8, 2, 5, 6],
    'Time (in months)': [16, 5, 9, 12]
})
names = ['Tom', 'Kris', 'Ahmad', 'Beau']

certificates_earned.index = names
longest_streak = pd.Series([13, 11, 9, 7], index=names)
certificates_earned['Longest streak'] = longest_streak

print(certificates_earned)
# Out:
#        Certificates  Time (in months)  Longest streak
# Tom               8                16              13
# Kris              2                 5              11
# Ahmad             5                 9               9
# Beau              6                12               7

# %%
s = pd.Series(['a', 3, np.nan, 1, np.nan])

print(s.notnull().sum())
# Out:
# 3

# %%
s = pd.Series([np.nan, 1, 2, np.nan, 3])
s = s.fillna(method='ffill')

print(s)
# Out:
# 0    NaN
# 1    1.0
# 2    2.0
# 3    2.0
# 4    3.0
# dtype: float64
# C:\Users\rames\AppData\Local\Temp\ipykernel_19908\703551071.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   s = s.fillna(method='ffill')

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
x = np.arange(-10, 11)
plt.figure(figsize=(12, 6))
plt.title("Plot title")

plt.plot(x, x ** 2)
plt.plot(x, -1 * (x ** 2))
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.title('Subplot')

plt.subplot(1,2,1)
plt.plot(x, x ** 2)
plt.plot(x, -1 * (x ** 2))
plt.show()
